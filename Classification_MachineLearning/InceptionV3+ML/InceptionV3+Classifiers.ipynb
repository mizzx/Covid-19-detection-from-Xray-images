# %% [markdown]
# Read excel file containing features extracted by InceptionV3

# %%
import pandas as pd

df = pd.read_excel("features_InceptionV3.xlsx")

# %%
df.head()

# %%
#train_test_split method of scikit learn library
from sklearn.model_selection import train_test_split
x_in = df.drop(['Unnamed: 0','Image_name', 'Xray_class'], axis=1)
y_out = df.Xray_class
xtrain, xtest, ytrain, ytest = train_test_split(x_in, y_out, test_size=0.2, shuffle=True, stratify=y_out)

# %% [markdown]
# KNN without CV

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestNeighbors

# %%
knn = KNeighborsClassifier()
knn.fit(xtrain, ytrain)
# Out:
# KNeighborsClassifier()

# %%
pred_knn = knn.predict(xtest)

# %%
print(accuracy_score(ytest, pred_knn))
# Out:
# 0.85

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cm = confusion_matrix(ytest, pred_knn)
classes=['normal', 'covid19', 'tb']
sns.heatmap(cm, annot=True, xticklabels=classes, yticklabels=classes,cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix of InceptionV3 + KNN classifier without CV')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix of InceptionV3 + KNN classifier without CV')

# %%
#plot roc multiclass
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from keras.utils import to_categorical

# %%
# Binarize the output
PRED = to_categorical(pred_knn, num_classes=3)
y = label_binarize(y_out, classes=[0,1,2])
n_classes = y.shape[1]

Y_test = to_categorical(ytest, num_classes=3)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
       fpr[i], tpr[i], _ = roc_curve(Y_test[:,i], PRED[:,i])
       roc_auc[i] = auc(fpr[i], tpr[i])

# %%
colors = ['blue', 'red', 'green']
cls = {0:'normal', 1:'covid19', 2:'tb'}
for i, color ,c in zip(range(n_classes), colors, cls.values()):
    plt.plot(fpr[i], tpr[i], color=color, lw=0.5,
             label='ROC curve of '+c+ '(AUC = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--',linestyle='--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC of Inceptionv3 + KNN classifier without CV')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\Users\Zul\AppData\Local\Temp\ipykernel_13292\1513137649.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.plot([0, 1], [0, 1], 'k--',linestyle='--')

# %% [markdown]
# KNN with CV

# %%
from sklearn.model_selection import KFold, cross_val_score, cross_val_predict
from sklearn import metrics
from sklearn.metrics import roc_auc_score

# %%
x_ar = x_in.to_numpy()
y_ar = y_out.to_numpy()

# %%
# 10 fold cv

kf10_knn = KFold(n_splits = 10, shuffle=True)

scores2_knn = cross_val_score(knn, x_ar, y_ar, cv = kf10_knn)

print("Cross Validation Scores: ", scores2_knn)
print("Average CV Score: ", scores2_knn.mean())
print("Number of CV Scores used in Average: ", len(scores2_knn))
# Out:
# Cross Validation Scores:  [0.87777778 0.92222222 0.87777778 0.86666667 0.87777778 0.87777778
#  0.93333333 0.88888889 0.86666667 0.91111111]
# Average CV Score:  0.89
# Number of CV Scores used in Average:  10

# %%
# Make cross validated predictions
predictions = cross_val_predict(knn, x_ar, y_ar, cv=kf10_knn)

# %%
# Binarize the output
PREDcv = to_categorical(predictions, num_classes=3)

Ycv = to_categorical(y_ar, num_classes=3)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
       fpr[i], tpr[i], _ = roc_curve(Ycv[:,i], PREDcv[:,i])
       roc_auc[i] = auc(fpr[i], tpr[i])

# %%
colors = ['blue', 'red', 'green']
cls = {0:'normal', 1:'covid19', 2:'tb'}
for i, color ,c in zip(range(n_classes), colors, cls.values()):
    plt.plot(fpr[i], tpr[i], color=color, lw=0.5,
             label='ROC curve of '+c+ '(AUC = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--',linestyle='--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC of Inceptionv3 + KNN classifier with CV')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\Users\Zul\AppData\Local\Temp\ipykernel_13292\2866437957.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.plot([0, 1], [0, 1], 'k--',linestyle='--')

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth = 4, random_state = 0)
rfc.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(max_depth=4, random_state=0)

# %%
preds_rf=rfc.predict(xtest)

# %%
print(accuracy_score(ytest, preds_rf))
# Out:
# 0.8388888888888889

# %%
cm = confusion_matrix(ytest, preds_rf)
classes=['normal', 'covid19', 'tb']
sns.heatmap(cm, annot=True, xticklabels=classes, yticklabels=classes,cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix of Inceptionv3 + RF classifier without CV')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix of Inceptionv3 + RF classifier without CV')

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest, preds_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.72      0.82        60
#            1       0.74      0.93      0.82        60
#            2       0.88      0.87      0.87        60
#
#     accuracy                           0.84       180
#    macro avg       0.86      0.84      0.84       180
# weighted avg       0.86      0.84      0.84       180

# %%
# Binarize the output
PRED = to_categorical(preds_rf, num_classes=3)
y = label_binarize(y_out, classes=[0,1,2])
n_classes = y.shape[1]

Y_test = to_categorical(ytest, num_classes=3)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
       fpr[i], tpr[i], _ = roc_curve(Y_test[:,i], PRED[:,i])
       roc_auc[i] = auc(fpr[i], tpr[i])

# %%
colors = ['blue', 'red', 'green']
cls = {0:'normal', 1:'covid19', 2:'tb'}
for i, color ,c in zip(range(n_classes), colors, cls.values()):
    plt.plot(fpr[i], tpr[i], color=color, lw=0.5,
             label='ROC curve of '+c+ '(AUC = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--',linestyle='--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC of Inceptionv3 + RF classifier without CV')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\Users\Zul\AppData\Local\Temp\ipykernel_13292\840805315.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.plot([0, 1], [0, 1], 'k--',linestyle='--')

# %% [markdown]
# RF with CV

# %%
# 10 fold cv

kf10_RF = KFold(n_splits = 10, shuffle=True)

scores2_RF = cross_val_score(rfc, x_ar, y_ar, cv = kf10_RF)

print("Cross Validation Scores: ", scores2_RF)
print("Average CV Score: ", scores2_RF.mean())
print("Number of CV Scores used in Average: ", len(scores2_RF))
# Out:
# Cross Validation Scores:  [0.88888889 0.91111111 0.86666667 0.9        0.87777778 0.87777778
#  0.91111111 0.93333333 0.9        0.84444444]
# Average CV Score:  0.8911111111111112
# Number of CV Scores used in Average:  10

# %%
# Make cross validated predictions
predictions = cross_val_predict(rfc, x_ar, y_ar, cv=kf10_RF)

# %%
# Binarize the output
PREDcv = to_categorical(predictions, num_classes=3)

Ycv = to_categorical(y_ar, num_classes=3)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
       fpr[i], tpr[i], _ = roc_curve(Ycv[:,i], PREDcv[:,i])
       roc_auc[i] = auc(fpr[i], tpr[i])

# %%
colors = ['blue', 'red', 'green']
cls = {0:'normal', 1:'covid19', 2:'tb'}
for i, color ,c in zip(range(n_classes), colors, cls.values()):
    plt.plot(fpr[i], tpr[i], color=color, lw=0.5,
             label='ROC curve of '+c+ '(AUC = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--',linestyle='--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC of Inceptionv3 + RF classifier with CV')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\Users\Zul\AppData\Local\Temp\ipykernel_13292\2325730304.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.plot([0, 1], [0, 1], 'k--',linestyle='--')

# %% [markdown]
# ANN

# %%
from sklearn.neural_network import MLPClassifier
ann = MLPClassifier(solver='lbfgs',alpha=1e-5, random_state=0)
ann.fit(xtrain, ytrain)
# Out:
# MLPClassifier(alpha=1e-05, random_state=0, solver='lbfgs')

# %%
preds_ann=ann.predict(xtest)

# %%
print(accuracy_score(ytest, preds_ann))
# Out:
# 0.9222222222222223

# %%
cm = confusion_matrix(ytest, preds_ann)
classes=['normal', 'covid19', 'tb']
sns.heatmap(cm, annot=True, xticklabels=classes, yticklabels=classes,cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix of Inceptionv3 + ANN classifier without CV')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix of Inceptionv3 + ANN classifier without CV')

# %%
print(classification_report(ytest, preds_ann))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92        60
#            1       0.89      0.93      0.91        60
#            2       0.95      0.93      0.94        60
#
#     accuracy                           0.92       180
#    macro avg       0.92      0.92      0.92       180
# weighted avg       0.92      0.92      0.92       180

# %%
# Binarize the output
PRED = to_categorical(preds_ann, num_classes=3)
y = label_binarize(y_out, classes=[0,1,2])
n_classes = y.shape[1]

Y_test = to_categorical(ytest, num_classes=3)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
       fpr[i], tpr[i], _ = roc_curve(Y_test[:,i], PRED[:,i])
       roc_auc[i] = auc(fpr[i], tpr[i])

# %%
colors = ['blue', 'red', 'green']
cls = {0:'normal', 1:'covid19', 2:'tb'}
for i, color ,c in zip(range(n_classes), colors, cls.values()):
    plt.plot(fpr[i], tpr[i], color=color, lw=0.5,
             label='ROC curve of '+c+ '(AUC = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--',linestyle='--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC of Inceptionv3 + ANN classifier without CV')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\Users\Zul\AppData\Local\Temp\ipykernel_13292\3948153865.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.plot([0, 1], [0, 1], 'k--',linestyle='--')

# %% [markdown]
# ANN with CV

# %%
# 10 fold cv

kf10_ann = KFold(n_splits = 10, shuffle=True)

scores2_ann = cross_val_score(ann, x_ar, y_ar, cv = kf10_ann)

print("Cross Validation Scores: ", scores2_ann)
print("Average CV Score: ", scores2_ann.mean())
print("Number of CV Scores used in Average: ", len(scores2_ann))
# Out:
# Cross Validation Scores:  [0.97777778 0.97777778 0.9        0.94444444 0.94444444 0.91111111
#  0.94444444 0.92222222 0.88888889 0.88888889]
# Average CV Score:  0.93
# Number of CV Scores used in Average:  10

# %%
# Make cross validated predictions
predictions = cross_val_predict(ann, x_ar, y_ar, cv=kf10_ann)

# %%
# Binarize the output
PREDcv = to_categorical(predictions, num_classes=3)

Ycv = to_categorical(y_ar, num_classes=3)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
       fpr[i], tpr[i], _ = roc_curve(Ycv[:,i], PREDcv[:,i])
       roc_auc[i] = auc(fpr[i], tpr[i])

# %%
colors = ['blue', 'red', 'green']
cls = {0:'normal', 1:'covid19', 2:'tb'}
for i, color ,c in zip(range(n_classes), colors, cls.values()):
    plt.plot(fpr[i], tpr[i], color=color, lw=0.5,
             label='ROC curve of '+c+ '(AUC = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--',linestyle='--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC of Inceptionv3 + ANN classifier with CV')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\Users\Zul\AppData\Local\Temp\ipykernel_13292\3039873764.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.plot([0, 1], [0, 1], 'k--',linestyle='--')
